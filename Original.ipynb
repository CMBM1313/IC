# %% [markdown]
# <a href="https://colab.research.google.com/github/CMBM1313/IC/blob/main/Original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time


#Constants
M = 250
V = 1.0
target = 1e-5
delta = 1.0

phi = np.zeros([M, M])
phi[0, :] = V
phi[M - 1, :] = V
phi[:, 0] = V
phi[:, M - 1] = V

phi[120:133, 120:133] = -V
phiprime = np.empty([M, M], float)

phiprime[0, :] = phi[0, :]
phiprime[M - 1, :] = phi[M - 1, :]
phiprime[:, 0] = phi[:, 0]
phiprime[:, M - 1] = phi[:, M - 1]
phiprime[120:133, 120:133] = phi[120:133, 120:133]

while delta > target:
    phiprime = (np.roll(phi, 1, axis = 0) + np.roll(phi, -1, axis = 0) + np.roll(phi, 1, axis = 1) + np.roll(phi, -1, axis = 1))/4

    phiprime[0, :] = phi[0, :]
    phiprime[M - 1, :] = phi[M - 1, :]
    phiprime[:, 0] = phi[:, 0]
    phiprime[:, M - 1] = phi[:, M - 1]
    phiprime[120:133, 120:133] = phi[120:133, 120:133]
    delta = np.max(np.abs(phi - phiprime))
    phi, phiprime = phiprime, phi

plt.imshow(phi)
plt.colorbar()
plt.show()
# Out:
# 5.796647310256958
# 250
# 18274
